# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [2,4,6,7,8,9]
y = [1,2,3]
z = [9, 6, 3]
plt.plot(x)
plt.plot(y)
plt.plot(z)
plt.title("Python for DataScience")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["This is x axis", "This is y axis", "This is z axis"])
plt.show()
